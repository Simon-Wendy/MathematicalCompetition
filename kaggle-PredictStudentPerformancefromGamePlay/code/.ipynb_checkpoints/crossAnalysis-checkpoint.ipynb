# %%
import numpy as np,pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_columns',200)
pd.set_option('max_colwidth',200)
pd.set_option('max_rows',200)

# %%
train = pd.read_csv('../dataset/train.csv')
test = pd.read_csv('../dataset/test.csv')
train.head()
# Out:
#           session_id  index  elapsed_time      event_name   name  level  page  \
# 0  20090312431273200      0             0  cutscene_click  basic      0   NaN
# 1  20090312431273200      1          1323    person_click  basic      0   NaN
# 2  20090312431273200      2           831    person_click  basic      0   NaN
# 3  20090312431273200      3          1147    person_click  basic      0   NaN
# 4  20090312431273200      4          1863    person_click  basic      0   NaN
#
#    room_coor_x  room_coor_y  screen_coor_x  screen_coor_y  hover_duration  \
# 0  -413.991405  -159.314686          380.0          494.0             NaN
# 1  -413.991405  -159.314686          380.0          494.0             NaN
# 2  -413.991405  -159.314686          380.0          494.0             NaN
# 3  -413.991405  -159.314686          380.0          494.0             NaN
# 4  -412.991405  -159.314686          381.0          494.0             NaN
#
#                             text    fqid                       room_fqid  \
# 0                      undefined   intro  tunic.historicalsociety.closet
# 1  Whatcha doing over there, Jo?  gramps  tunic.historicalsociety.closet
# 2         Just talking to Teddy.  gramps  tunic.historicalsociety.closet
# 3     I gotta run to my meeting!  gramps  tunic.historicalsociety.closet
# 4            Can I come, Gramps?  gramps  tunic.historicalsociety.closet
#
#                                             text_fqid  fullscreen  hq  music  \
# 0                tunic.historicalsociety.closet.intro         NaN NaN    NaN
# 1  tunic.historicalsociety.closet.gramps.intro_0_cs_0         NaN NaN    NaN
# 2  tunic.historicalsociety.closet.gramps.intro_0_cs_0         NaN NaN    NaN
# 3  tunic.historicalsociety.closet.gramps.intro_0_cs_0         NaN NaN    NaN
# 4  tunic.historicalsociety.closet.gramps.intro_0_cs_0         NaN NaN    NaN
#
#   level_group
# 0         0-4
# 1         0-4
# 2         0-4
# 3         0-4
# 4         0-4

# %%
train_missing = train.isnull().sum()/len(train) * 100
test_missing = test.isnull().sum()/len(test) * 100
fig,axs = plt.subplots(2,1,figsize = (20,20))
g1 = sns.barplot(x=train_missing.index,y=train_missing.values,ax=axs[0])
g1.set_title('Every columns of missing values in train(%)',fontsize=18)
g1.bar_label(g1.containers[0],labels=[f'{x.get_height():.2f}' for x in g1.containers[0]])
g1.xaxis.set_tick_params(rotation=45)
g2 = sns.barplot(x=test_missing.index,y=test_missing.values,ax=axs[1])
g2.set_title('Every columns of missing values in test(%)',fontsize=18)
g2.bar_label(g2.containers[0],labels=[f'{x.get_height():.2f}' for x in g2.containers[0]])
g2.xaxis.set_tick_params(rotation=45)
plt.show()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13174211 entries, 0 to 13174210
# Data columns (total 20 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   session_id      int64
#  1   index           int64
#  2   elapsed_time    int64
#  3   event_name      object
#  4   name            object
#  5   level           int64
#  6   page            float64
#  7   room_coor_x     float64
#  8   room_coor_y     float64
#  9   screen_coor_x   float64
#  10  screen_coor_y   float64
#  11  hover_duration  float64
#  12  text            object
#  13  fqid            object
#  14  room_fqid       object
#  15  text_fqid       object
#  16  fullscreen      float64
#  17  hq              float64
#  18  music           float64
#  19  level_group     object
# dtypes: float64(9), int64(4), object(7)
# memory usage: 2.0+ GB

# %%
level_groups = train['level_group'].unique().tolist()
fig,axs = plt.subplots(3,1,figsize=(20,30))
for lg in level_groups:
    temp = train[train['level_group']==lg]['event_name'].value_counts()
    g = sns.barplot(x = temp.index,y = temp.values,ax=axs[level_groups.index(lg)])
    g.set_title('level_group: {} event_name counts'.format(lg),fontsize=18)
    g.bar_label(g.containers[0])
    g.xaxis.set_tick_params(rotation=45)
plt.show()
del level_groups,fig,axs,g

# %%
len(train['session_id'].unique())
# Out:
# 11779

# %%
level_groups = train['level_group'].unique().tolist()
fig,axs = plt.subplots(1,3,figsize=(20,10))
for lg in level_groups:
    temp = train[train['level_group']==lg]['name'].value_counts()
    g = sns.barplot(x = temp.index,y = temp.values,ax=axs[level_groups.index(lg)])
    g.set_title('level_group: {} name counts'.format(lg),fontsize=18)
    g.bar_label(g.containers[0],label=[f'{x.get_height():.1f}' for x in g.containers[0]])
    g.xaxis.set_tick_params(rotation=45)
plt.show()
del level_groups,fig,axs,g

# %%
level_groups = train['level_group'].unique().tolist()
fig,axs = plt.subplots(1,3,figsize=(20,10))
for lg in level_groups:
    temp = test[test['level_group']==lg]['name'].value_counts()
    g = sns.barplot(x = temp.index,y = temp.values,ax=axs[level_groups.index(lg)])
    g.set_title('level_group: {} name counts'.format(lg),fontsize=18)
    g.bar_label(g.containers[0],label=[f'{x.get_height():.1f}' for x in g.containers[0]])
    g.xaxis.set_tick_params(rotation=45)
plt.show()
del level_groups,fig,axs,g

# %%
name = train['name'].unique().tolist()
fig,axs = plt.subplots(len(name),1,figsize=(20,7*len(name)))
for n in name:
    temp = train[train['name']==n]['event_name'].value_counts()
    g = sns.barplot(x = temp.index,y = temp.values,ax=axs[name.index(n)])
    g.set_title('name: {} event_name counts'.format(n),fontsize=18)
    g.bar_label(g.containers[0],label=[f'{x.get_height():.1f}' for x in g.containers[0]])
    g.xaxis.set_tick_params(rotation=45)
plt.show()
del name,fig,axs,g

# %%
plt.figure(figsize=(20,60))
g = sns.displot(train,x='event_name',col='level_group',row='name')
plt.xticks(rotation=45)
plt.show()
del g

# %%
groups = train['level_group'].unique().tolist()
fig,axs = plt.subplots(len(groups),1,figsize=(20,7*len(groups)))
for g in groups:
    temp = train[train['level_group']==g]['level'].value_counts()
    g = sns.barplot(x = temp.index,y = temp.values,ax=axs[groups.index(g)])
    g.set_title('level_group: {} level counts'.format(n),fontsize=18)
    g.bar_label(g.containers[0],label=[f'{x.get_height():.1f}' for x in g.containers[0]])
plt.show()
del groups,fig,axs,g

# %%
# Out:
# worker                            939555
# archivist                         563259
# gramps                            561000
# wells                             394234
# toentry                           392221
# confrontation                     348723
# crane_ranger                      251943
# groupconvo                        227881
# flag_girl                         224758
# tomap                             202176
# tostacks                          169123
# tobasement                        162947
# archivist_glasses                 158513
# boss                              151822
# journals                          150014
# seescratches                      146223
# groupconvo_flag                   136133
# cs                                129873
# teddy                             119041
# expert                            118147
# businesscards                     111142
# ch3start                          107078
# tunic.historicalsociety           106827
# tofrontdesk                        99897
# savedteddy                         93057
# plaque                             91590
# glasses                            91466
# tunic.drycleaner                   90982
# reader_flag                        83196
# tunic.library                      81727
# tracks                             76453
# tunic.capitol_2                    74897
# trigger_scarf                      72360
# reader                             67638
# directory                          65788
# tunic.capitol_1                    57986
# journals.pic_0.next                55963
# unlockdoor                         55829
# tunic                              55599
# what_happened                      54651
# tunic.kohlcenter                   52435
# tunic.humanecology                 51033
# colorbook                          49961
# logbook                            48174
# businesscards.card_0.next          45851
# journals.hub.topics                45806
# logbook.page.bingo                 43801
# journals.pic_1.next                43698
# journals_flag                      41540
# reader.paper0.next                 38482
# tracks.hub.deer                    37567
# reader_flag.paper0.next            36995
# trigger_coffee                     35978
# wellsbadge                         34752
# journals.pic_2.next                33771
# tomicrofiche                       33504
# journals_flag.pic_0.bingo          32738
# plaque.face.date                   32644
# notebook                           32490
# tocloset_dirty                     32059
# businesscards.card_bingo.bingo     32001
# businesscards.card_1.next          31292
# tunic.wildlife                     31245
# tunic.hub.slip                     30680
# tocage                             30595
# journals.pic_2.bingo               30065
# tocollectionflag                   30014
# tocollection                       29741
# chap4_finale_c                     29471
# chap2_finale_c                     29452
# lockeddoor                         29244
# journals_flag.hub.topics           28950
# tunic.capitol_0                    28657
# reader_flag.paper2.bingo           28138
# photo                              27748
# tunic.flaghouse                    27195
# reader.paper1.next                 26914
# directory.closeup.archivist        26668
# intro                              26195
# businesscards.card_bingo.next      25997
# reader.paper2.bingo                25995
# retirement_letter                  25376
# remove_cup                         24643
# journals_flag.pic_0.next           24442
# magnify                            24437
# coffee                             24294
# key                                23980
# togrampa                           23715
# reader_flag.paper1.next            22740
# janitor                            21672
# tohallway                          21413
# chap1_finale                       21397
# report                             19253
# outtolunch                         14988
# journals_flag.hub.topics_old       13962
# journals_flag.pic_1.next           12446
# reader.paper2.next                 12368
# chap1_finale_c                     12097
# reader_flag.paper2.next            11280
# door_block_talk                     9854
# journals_flag.pic_1.bingo           9560
# journals_flag.pic_2.next            8485
# journals_flag.pic_2.bingo           8286
# block_magnify                       7883
# reader.paper0.prev                  7265
# block                               6624
# reader_flag.paper0.prev             6384
# block_0                             5981
# door_block_clean                    5188
# reader.paper2.prev                  5093
# reader.paper1.prev                  3953
# doorblock                           3729
# tocloset                            3414
# reader_flag.paper2.prev             2936
# reader_flag.paper1.prev             2805
# block_tomap2                        1947
# journals_flag.pic_0_old.next        1843
# journals_flag.pic_1_old.next        1277
# block_tocollection                  1104
# block_nelson                        1099
# journals_flag.pic_2_old.next         993
# block_tomap1                         881
# block_badge                          854
# need_glasses                         675
# block_badge_2                        508
# fox                                  166
# block_1                               25
# Name: fqid, dtype: int64

# %%
fqid = train['fqid'].value_counts()
plt.figure(figsize=(20,10))
g = sns.barplot(x=fqid.index, y = fqid.values)
g.set_title('fqid counts',fontsize=18)
g.xaxis.set_tick_params(rotation=90)
g.bar_label(g.containers[0])
plt.show()

# %%
groups = train['level_group'].unique().tolist()
fig,axs = plt.subplots(len(groups),1,figsize=(20,10*len(groups)))
for n in groups:
    temp = train[train['level_group']==n]['fqid'].value_counts()
    g = sns.barplot(x = temp.index,y = temp.values,ax=axs[groups.index(n)])
    g.set_title('name: {} event_name counts'.format(n),fontsize=18)
    g.bar_label(g.containers[0],label=[f'{x.get_height():.1f}' for x in g.containers[0]])
    g.xaxis.set_tick_params(rotation=45)
plt.show()
del groups,fig,axs,g,n

# %%
fqid_data = train.copy()
fqid_data['fqid_split_1'] = fqid_data['fqid'].astype(str).map(lambda x:x.split('.')[-1])
fqid_data['fqid_split_0'] = fqid_data['fqid'].astype(str).map(lambda x:x.split('.')[0])
fqid_data['fqid_split_0'].value_counts()
# Out:
# nan                   4159648
# worker                 939555
# tunic                  689263
# archivist              563259
# gramps                 561000
# wells                  394234
# toentry                392221
# journals               359317
# confrontation          348723
# crane_ranger           251943
# businesscards          246283
# groupconvo             227881
# flag_girl              224758
# tomap                  202176
# reader_flag            194474
# reader                 187708
# journals_flag          184522
# tostacks               169123
# tobasement             162947
# archivist_glasses      158513
# boss                   151822
# seescratches           146223
# groupconvo_flag        136133
# cs                     129873
# plaque                 124234
# teddy                  119041
# expert                 118147
# tracks                 114020
# ch3start               107078
# tofrontdesk             99897
# savedteddy              93057
# directory               92456
# logbook                 91975
# glasses                 91466
# trigger_scarf           72360
# unlockdoor              55829
# what_happened           54651
# colorbook               49961
# trigger_coffee          35978
# wellsbadge              34752
# tomicrofiche            33504
# notebook                32490
# tocloset_dirty          32059
# tocage                  30595
# tocollectionflag        30014
# tocollection            29741
# chap4_finale_c          29471
# chap2_finale_c          29452
# lockeddoor              29244
# photo                   27748
# intro                   26195
# retirement_letter       25376
# remove_cup              24643
# magnify                 24437
# coffee                  24294
# key                     23980
# togrampa                23715
# janitor                 21672
# tohallway               21413
# chap1_finale            21397
# report                  19253
# outtolunch              14988
# chap1_finale_c          12097
# door_block_talk          9854
# block_magnify            7883
# block                    6624
# block_0                  5981
# door_block_clean         5188
# doorblock                3729
# tocloset                 3414
# block_tomap2             1947
# block_tocollection       1104
# block_nelson             1099
# block_tomap1              881
# block_badge               854
# need_glasses              675
# block_badge_2             508
# fox                       166
# block_1                    25
# Name: fqid_split_0, dtype: int64

# %%
fqid = fqid_data['fqid'].value_counts()
fqids1 = fqid_data['fqid_split_0'].value_counts()
fqids2 = fqid_data['fqid_split_1'].value_counts()
fig,axs = plt.subplots(3,1,figsize=(20,30))
g = sns.barplot(x = fqid.index, y = fqid.values, ax=axs[0])
g.set_title('Counts of fqid',fontsize=18)
g.xaxis.set_tick_params(rotation=90)

g1 = sns.barplot(x = fqids1.index, y = fqids1.values, ax=axs[1])
g1.set_title('Counts of fqid_split_0',fontsize=18)
g1.xaxis.set_tick_params(rotation=90)

g2 = sns.barplot(x = fqids2.index, y = fqids2.values, ax=axs[2])
g2.set_title('Counts of fqid_split_1',fontsize=18)
g2.xaxis.set_tick_params(rotation=90)
plt.show()
print('the fqid length: ',len(fqid))
print('the fqid_split_0 length: ',len(fqids1))
print('the fqid_split_1 length: ',len(fqids2))
del fqid,fqids1,fqids2
# Out:
# the fqid length:  127
# the fqid_split_0 length:  79
# the fqid_split_1 length:  97

# %%
groups = train['level_group'].unique().tolist()
fig,axs = plt.subplots(len(groups),1,figsize=(20,10*len(groups)))
for n in groups:
    temp = fqid_data[fqid_data['level_group']==n]['fqid_split_0'].value_counts()
    g = sns.barplot(x = temp.index,y = temp.values,ax=axs[groups.index(n)])
    g.set_title('name: {} fqid_split_0 counts'.format(n),fontsize=18)
    g.bar_label(g.containers[0],label=[f'{x.get_height():.1f}' for x in g.containers[0]])
    g.xaxis.set_tick_params(rotation=90)
plt.show()
del groups,fig,axs,g,n

# %%
groups = train['level_group'].unique().tolist()
fig,axs = plt.subplots(len(groups),1,figsize=(20,10*len(groups)))
for n in groups:
    temp = fqid_data[fqid_data['level_group']==n]['fqid_split_1'].value_counts()
    g = sns.barplot(x = temp.index,y = temp.values,ax=axs[groups.index(n)])
    g.set_title('name: {} fqid_split_1 counts'.format(n),fontsize=18)
    g.bar_label(g.containers[0],label=[f'{x.get_height():.1f}' for x in g.containers[0]])
    g.xaxis.set_tick_params(rotation=90)
plt.show()
del groups,fig,axs,g,n

# %%
fqid_data['fqid_split_lenth'] = fqid_data['fqid'].astype(str).map(lambda x:len(x.split('.')))
fqid_data['fqid_split_lenth'].value_counts()
# Out:
# 1    11681093
# 3      890134
# 2      602984
# Name: fqid_split_lenth, dtype: int64

# %%
groups = fqid_data['level_group'].unique().tolist()
fig,axs = plt.subplots(1,3,figsize=(20,10))
for n in groups:
    temp = fqid_data[fqid_data['level_group']==n]['fqid_split_lenth'].value_counts()
    g = sns.barplot(x = temp.index,y = temp.values,ax=axs[groups.index(n)])
    g.set_title('name: {} fqid_split_lenth counts'.format(n),fontsize=18)
    g.bar_label(g.containers[0],label=[f'{x.get_height():.1f}' for x in g.containers[0]])
    g.xaxis.set_tick_params(rotation=90)
plt.show()
del groups,fig,axs,g,n,temp

# %%
plt.figure(figsize=(20,20))
g = sns.displot(fqid_data,x='event_name',col='level_group',row='fqid_split_lenth')
plt.show()
